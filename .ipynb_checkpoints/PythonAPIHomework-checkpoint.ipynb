# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
#import openweathermapy

# %%
# Output File (CSV)
output_datafile = "outputdata/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=lat_range[0], high=lat_range[1], size=1500)
lngs = np.random.uniform(low=lng_range[0], high=lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city by passing lat and lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # append unique city to the list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print("There are {} cities found from random geo-coordinates.".format(len(cities)))
# Out:
# There are 620 cities found from random geo-coordinates.

# %% [markdown]
# # Create a set of random lat and lng combinations

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
# Identify nearest city for each lat, lng combination

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
unit = "Imperial"

#api_key = "enter api key to execute"

base_url = f"http://api.openweathermap.org/data/2.5/weather?"
param = {"appid" : weather_api_key,
         "units" : unit}

# Create DataFrame with below parameters
city_weather_df = pd.DataFrame(columns=["City",
                                        "Cloudiness(%)",
                                        "Country",
                                        "Date",
                                        "Humidity(%)",
                                        "Lat",
                                        "Lng", 
                                        "Max Temp(F)",
                                        "Wind Speed(mph)"])

# get local current time
def current_date():
    localtime = time.asctime( time.localtime(time.time()) )
    return localtime.split(' ')[1]+"/"+localtime.split(' ')[2]+"/"+localtime.split(' ')[4]


print("Beginning Data Retrieval")
print("-----------------------------------")


# store each city weather information on DataFrame
i = 0
not_found = 0
for city in cities:
    param["q"] = city
    
    # Perform a weather check on each of the cities using a series of successive API calls    
    data = requests.get(base_url, params=param).json()
    try:
        city_weather_df.loc[i, "City"] = data["name"]
        city_weather_df.loc[i, "Cloudiness(%)"] = data["clouds"]["all"]
        city_weather_df.loc[i, "Country"] = data["sys"]["country"]
        city_weather_df.loc[i, "Date"] = current_date()
        city_weather_df.loc[i, "Humidity(%)"] = data["main"]["humidity"]
        city_weather_df.loc[i, "Lat"] = data["coord"]["lat"]
        city_weather_df.loc[i, "Lng"] = data["coord"]["lon"]
        city_weather_df.loc[i, "Max Temp(F)"] = data["main"]["temp_max"]
        city_weather_df.loc[i, "Wind Speed(mph)"] = data["wind"]["speed"]
        
        i += 1
        # Include a print log of each city as it's being processed with the city number and city name.
        print("Processing Record {:3d} of set {} | {} ".format(i, len(cities), data['name']))
              
    except KeyError:
        print("(Total {} cities out of {} not found...) ".format(not_found + 1, len(cities)))
        not_found += 1

print(f"""
-------------------------------------------
Data Retrieval Completed
-------------------------------------------""")
# Out:
# Beginning Data Retrieval
# -----------------------------------
# Processing Record   1 of set 612 | Athabasca
# Processing Record   2 of set 612 | Cape Town
# Processing Record   3 of set 612 | Aklavik
# Processing Record   4 of set 612 | Tuktoyaktuk
# Processing Record   5 of set 612 | Kosh-Agach
# Processing Record   6 of set 612 | Avarua
# Processing Record   7 of set 612 | Carnarvon
# Processing Record   8 of set 612 | Provideniya
# Processing Record   9 of set 612 | Amahai
# Processing Record  10 of set 612 | Norman Wells
# Processing Record  11 of set 612 | Punta Arenas
# Processing Record  12 of set 612 | Warmbad
# (Total 1 cities out of 612 not found...)
# Processing Record  13 of set 612 | Canmore
# Processing Record  14 of set 612 | Coyhaique
# Processing Record  15 of set 612 | Pangkalanbuun
# Processing Record  16 of set 612 | Ponta do Sol
# Processing Record  17 of set 612 | Pacific Grove
# Processing Record  18 of set 612 | Saldanha
# Processing Record  19 of set 612 | Tabuk
# Processing Record  20 of set 612 | Port Alfred
# Processing Record  21 of set 612 | Mount Isa
# Processing Record  22 of set 612 | Lebu
# Processing Record  23 of set 612 | Tasiilaq
# (Total 2 cities out of 612 not found...)
# Processing Record  24 of set 612 | New Norfolk
# Processing Record  25 of set 612 | Hertford
# Processing Record  26 of set 612 | Vaini
# Processing Record  27 of set 612 | Kavaratti
# Processing Record  28 of set 612 | Bluff
# Processing Record  29 of set 612 | Harper
# Processing Record  30 of set 612 | Acapulco de Juárez
# Processing Record  31 of set 612 | Kruisfontein
# Processing Record  32 of set 612 | Oytal
# Processing Record  33 of set 612 | Weatherford
# Processing Record  34 of set 612 | George Town
# Processing Record  35 of set 612 | Naze
# Processing Record  36 of set 612 | Bafia
# Processing Record  37 of set 612 | Chokurdakh
# Processing Record  38 of set 612 | Butaritari
# Processing Record  39 of set 612 | Tiksi
# Processing Record  40 of set 612 | Novobelokatay
# (Total 3 cities out of 612 not found...)
# Processing Record  41 of set 612 | Lamu
# Processing Record  42 of set 612 | Jamestown
# Processing Record  43 of set 612 | Hilo
# Processing Record  44 of set 612 | Castro
# Processing Record  45 of set 612 | Kupang
# Processing Record  46 of set 612 | Clyde River
# (Total 4 cities out of 612 not found...)
# Processing Record  47 of set 612 | Salamiyah
# Processing Record  48 of set 612 | Rikitea
# Processing Record  49 of set 612 | Khatanga
# Processing Record  50 of set 612 | Caravelas
# Processing Record  51 of set 612 | Talnakh
# Processing Record  52 of set 612 | Ancud
# Processing Record  53 of set 612 | Mataura
# Processing Record  54 of set 612 | Hobyo
# Processing Record  55 of set 612 | Ribeira Grande
# Processing Record  56 of set 612 | Albany
# Processing Record  57 of set 612 | San Cristobal
# (Total 5 cities out of 612 not found...)
# Processing Record  58 of set 612 | Thompson
# Processing Record  59 of set 612 | Marsaxlokk
# Processing Record  60 of set 612 | Anadyr
# Processing Record  61 of set 612 | Vostok
# Processing Record  62 of set 612 | Arraial do Cabo
# Processing Record  63 of set 612 | Gisborne
# Processing Record  64 of set 612 | Matagami
# Processing Record  65 of set 612 | Ucluelet
# Processing Record  66 of set 612 | Edd
# Processing Record  67 of set 612 | Loandjili
# Processing Record  68 of set 612 | Villa Carlos Paz
# Processing Record  69 of set 612 | Suez
# Processing Record  70 of set 612 | Sioux Lookout
# Processing Record  71 of set 612 | Nikolskoye
# Processing Record  72 of set 612 | Yumen
# Processing Record  73 of set 612 | Iqaluit
# Processing Record  74 of set 612 | Puerto Ayora
# Processing Record  75 of set 612 | Los Llanos de Aridane
# Processing Record  76 of set 612 | Kīhei
# Processing Record  77 of set 612 | Mbanza-Ngungu
# Processing Record  78 of set 612 | Bac Lieu
# Processing Record  79 of set 612 | Preobrazheniye
# Processing Record  80 of set 612 | Ushuaia
# Processing Record  81 of set 612 | La Ronge
# Processing Record  82 of set 612 | Hobart
# (Total 6 cities out of 612 not found...)
# (Total 7 cities out of 612 not found...)
# Processing Record  83 of set 612 | Busselton
# Processing Record  84 of set 612 | Kapaa
# Processing Record  85 of set 612 | Simdega
# Processing Record  86 of set 612 | Hermanus
# Processing Record  87 of set 612 | Aba
# Processing Record  88 of set 612 | Ballina
# Processing Record  89 of set 612 | Asamankese
# Processing Record  90 of set 612 | Mayo
# Processing Record  91 of set 612 | Klaksvík
# Processing Record  92 of set 612 | Cayenne
# Processing Record  93 of set 612 | East London
# Processing Record  94 of set 612 | Fort Dodge
# (Total 8 cities out of 612 not found...)
# Processing Record  95 of set 612 | Kaitangata
# Processing Record  96 of set 612 | Severo-Kuril'sk
# Processing Record  97 of set 612 | Nelson Bay
# Processing Record  98 of set 612 | Cehegín
# Processing Record  99 of set 612 | Chui
# Processing Record 100 of set 612 | Taoudenni
# Processing Record 101 of set 612 | Ipu
# (Total 9 cities out of 612 not found...)
# Processing Record 102 of set 612 | Amga
# Processing Record 103 of set 612 | Broken Hill
# Processing Record 104 of set 612 | Iquitos
# Processing Record 105 of set 612 | Iquique
# Processing Record 106 of set 612 | Dargaville
# (Total 10 cities out of 612 not found...)
# Processing Record 107 of set 612 | Sawtell
# Processing Record 108 of set 612 | Gornozavodsk
# Processing Record 109 of set 612 | Taft
# Processing Record 110 of set 612 | Semporna
# Processing Record 111 of set 612 | Turukhansk
# Processing Record 112 of set 612 | Bredasdorp
# Processing Record 113 of set 612 | Opuwo
# Processing Record 114 of set 612 | Madoc
# Processing Record 115 of set 612 | Galveston
# Processing Record 116 of set 612 | Tura
# Processing Record 117 of set 612 | Chanika
# Processing Record 118 of set 612 | Russell
# Processing Record 119 of set 612 | Yellowknife
# Processing Record 120 of set 612 | Saint Paul Harbor
# Processing Record 121 of set 612 | Beian
# Processing Record 122 of set 612 | Shenkursk
# Processing Record 123 of set 612 | Zhob
# Processing Record 124 of set 612 | Preston
# Processing Record 125 of set 612 | Saint-Augustin
# Processing Record 126 of set 612 | Atuona
# Processing Record 127 of set 612 | Moose Factory
# Processing Record 128 of set 612 | Saint-Philippe
# Processing Record 129 of set 612 | Santa Quitéria do Maranhão
# (Total 11 cities out of 612 not found...)
# Processing Record 130 of set 612 | Ibrā’
# Processing Record 131 of set 612 | Saskylakh
# Processing Record 132 of set 612 | Zhengjiatun
# (Total 12 cities out of 612 not found...)
# Processing Record 133 of set 612 | Bengkulu
# Processing Record 134 of set 612 | Vardø
# Processing Record 135 of set 612 | General Pico
# Processing Record 136 of set 612 | Sorong
# Processing Record 137 of set 612 | La Romana
# Processing Record 138 of set 612 | Chany
# Processing Record 139 of set 612 | Daru
# Processing Record 140 of set 612 | Mossamedes
# Processing Record 141 of set 612 | Salalah
# (Total 13 cities out of 612 not found...)
# Processing Record 142 of set 612 | Katsuura
# Processing Record 143 of set 612 | Souillac
# Processing Record 144 of set 612 | Hualmay
# Processing Record 145 of set 612 | Mushie
# Processing Record 146 of set 612 | Lorengau
# Processing Record 147 of set 612 | Meadow Lake
# Processing Record 148 of set 612 | Geraldton
# Processing Record 149 of set 612 | Wenling
# Processing Record 150 of set 612 | Irtyshskiy
# Processing Record 151 of set 612 | Rumonge
# Processing Record 152 of set 612 | Sola
# Processing Record 153 of set 612 | Katobu
# Processing Record 154 of set 612 | Mount Gambier
# Processing Record 155 of set 612 | Hithadhoo
# Processing Record 156 of set 612 | Jacareacanga
# Processing Record 157 of set 612 | Tirat Carmel
# (Total 14 cities out of 612 not found...)
# Processing Record 158 of set 612 | Dunmore East
# Processing Record 159 of set 612 | Contamana
# Processing Record 160 of set 612 | Manaus
# Processing Record 161 of set 612 | Santhià
# Processing Record 162 of set 612 | Cherskiy
# Processing Record 163 of set 612 | Dubuque
# Processing Record 164 of set 612 | Borogontsy
# Processing Record 165 of set 612 | Mosal'sk
# Processing Record 166 of set 612 | Fairbanks
# Processing Record 167 of set 612 | Mindelo
# Processing Record 168 of set 612 | Arroyo de la Encomienda
# (Total 15 cities out of 612 not found...)
# Processing Record 169 of set 612 | Lompoc
# Processing Record 170 of set 612 | Abbeville
# Processing Record 171 of set 612 | Upernavik
# Processing Record 172 of set 612 | Orocué
# Processing Record 173 of set 612 | Bereda
# Processing Record 174 of set 612 | Bambous Virieux
# Processing Record 175 of set 612 | Kavieng
# Processing Record 176 of set 612 | Port Hawkesbury
# Processing Record 177 of set 612 | Makakilo City
# Processing Record 178 of set 612 | Torbay
# Processing Record 179 of set 612 | Nishihara
# Processing Record 180 of set 612 | Alta Floresta
# (Total 16 cities out of 612 not found...)
# Processing Record 181 of set 612 | Batabanó
# Processing Record 182 of set 612 | Bojnourd
# Processing Record 183 of set 612 | Coquimbo
# Processing Record 184 of set 612 | Esperance
# Processing Record 185 of set 612 | Liku
# Processing Record 186 of set 612 | Lázaro Cárdenas
# Processing Record 187 of set 612 | Qaanaaq
# Processing Record 188 of set 612 | Airai
# Processing Record 189 of set 612 | Husavik
# Processing Record 190 of set 612 | El Rosario
# Processing Record 191 of set 612 | Wanning
# Processing Record 192 of set 612 | Nyimba
# Processing Record 193 of set 612 | Sai Buri
# Processing Record 194 of set 612 | Nova Olímpia
# Processing Record 195 of set 612 | San Quintín
# Processing Record 196 of set 612 | Fort Nelson
# Processing Record 197 of set 612 | Longyan
# (Total 17 cities out of 612 not found...)
# Processing Record 198 of set 612 | Kumul
# Processing Record 199 of set 612 | Saint George
# Processing Record 200 of set 612 | Teya
# Processing Record 201 of set 612 | Kasempa
# Processing Record 202 of set 612 | Gagarin
# Processing Record 203 of set 612 | Kidal
# Processing Record 204 of set 612 | Clarksdale
# Processing Record 205 of set 612 | Cariré
# Processing Record 206 of set 612 | Ixtapa
# Processing Record 207 of set 612 | San Diego
# Processing Record 208 of set 612 | Port Hedland
# Processing Record 209 of set 612 | Soyo
# Processing Record 210 of set 612 | Sokołów Podlaski
# Processing Record 211 of set 612 | Mar del Plata
# (Total 18 cities out of 612 not found...)
# Processing Record 212 of set 612 | Drexel Heights
# Processing Record 213 of set 612 | Viedma
# Processing Record 214 of set 612 | Porto-Novo
# Processing Record 215 of set 612 | Bethel
# Processing Record 216 of set 612 | Tuatapere
# Processing Record 217 of set 612 | Urdoma
# Processing Record 218 of set 612 | Constitución
# Processing Record 219 of set 612 | Ayan
# Processing Record 220 of set 612 | Sjøvegan
# (Total 19 cities out of 612 not found...)
# Processing Record 221 of set 612 | Nome
# Processing Record 222 of set 612 | Cuiluan
# Processing Record 223 of set 612 | Beringovskiy
# Processing Record 224 of set 612 | Shingū
# Processing Record 225 of set 612 | Portland
# Processing Record 226 of set 612 | Mayor Pablo Lagerenza
# Processing Record 227 of set 612 | Hasaki
# Processing Record 228 of set 612 | Berlevåg
# Processing Record 229 of set 612 | Tilichiki
# (Total 20 cities out of 612 not found...)
# Processing Record 230 of set 612 | Farah
# Processing Record 231 of set 612 | Nanortalik
# (Total 21 cities out of 612 not found...)
# Processing Record 232 of set 612 | Strezhevoy
# Processing Record 233 of set 612 | Mahébourg
# Processing Record 234 of set 612 | Longyearbyen
# Processing Record 235 of set 612 | Maniitsoq
# Processing Record 236 of set 612 | Yulara
# Processing Record 237 of set 612 | Dikson
# Processing Record 238 of set 612 | Shache
# Processing Record 239 of set 612 | Nioro
# Processing Record 240 of set 612 | Benxi
# Processing Record 241 of set 612 | El Vigia
# Processing Record 242 of set 612 | Kpandae
# Processing Record 243 of set 612 | Ust'-Kut
# Processing Record 244 of set 612 | Isangel
# Processing Record 245 of set 612 | Svilengrad
# Processing Record 246 of set 612 | Paamiut
# Processing Record 247 of set 612 | Stann Creek Town
# Processing Record 248 of set 612 | Acaraú
# Processing Record 249 of set 612 | Myitkyina
# Processing Record 250 of set 612 | San Ciro de Acosta
# Processing Record 251 of set 612 | Hong Kong
# Processing Record 252 of set 612 | Kribi
# Processing Record 253 of set 612 | Richards Bay
# Processing Record 254 of set 612 | Kawalu
# Processing Record 255 of set 612 | Half Moon Bay
# Processing Record 256 of set 612 | Lagos
# Processing Record 257 of set 612 | Makat
# Processing Record 258 of set 612 | Orange Cove
# Processing Record 259 of set 612 | Sur
# Processing Record 260 of set 612 | Alofi
# Processing Record 261 of set 612 | Okato
# Processing Record 262 of set 612 | Ilulissat
# Processing Record 263 of set 612 | Vyshestebliyevskaya
# Processing Record 264 of set 612 | Dingle
# Processing Record 265 of set 612 | Ternate
# Processing Record 266 of set 612 | Haizhou
# Processing Record 267 of set 612 | Virginia Beach
# (Total 22 cities out of 612 not found...)
# Processing Record 268 of set 612 | Annau
# Processing Record 269 of set 612 | Vuktyl
# Processing Record 270 of set 612 | Road Town
# Processing Record 271 of set 612 | Maşyāf
# Processing Record 272 of set 612 | Impfondo
# Processing Record 273 of set 612 | Buraidah
# Processing Record 274 of set 612 | Ostrovnoy
# (Total 23 cities out of 612 not found...)
# Processing Record 275 of set 612 | Namatanai
# Processing Record 276 of set 612 | Rye
# Processing Record 277 of set 612 | Santiago
# Processing Record 278 of set 612 | Panguipulli
# Processing Record 279 of set 612 | Khanbari
# Processing Record 280 of set 612 | Fortuna
# Processing Record 281 of set 612 | La Plata
# Processing Record 282 of set 612 | Guerrero Negro
# Processing Record 283 of set 612 | Price
# Processing Record 284 of set 612 | Laguna
# Processing Record 285 of set 612 | Cabo San Lucas
# Processing Record 286 of set 612 | Uttiramerūr
# Processing Record 287 of set 612 | Dixon
# Processing Record 288 of set 612 | São Filipe
# Processing Record 289 of set 612 | Pangnirtung
# Processing Record 290 of set 612 | Macon
# Processing Record 291 of set 612 | Tvøroyri
# Processing Record 292 of set 612 | Ordzhonīkīdze
# Processing Record 293 of set 612 | Cockburn Town
# Processing Record 294 of set 612 | Touros
# Processing Record 295 of set 612 | Kangaatsiaq
# Processing Record 296 of set 612 | Ha Giang
# Processing Record 297 of set 612 | Auki
# Processing Record 298 of set 612 | Freeport
# Processing Record 299 of set 612 | El Corpus
# Processing Record 300 of set 612 | College
# Processing Record 301 of set 612 | Qarqīn
# Processing Record 302 of set 612 | Maceió
# Processing Record 303 of set 612 | Port Lincoln
# Processing Record 304 of set 612 | Morehead
# Processing Record 305 of set 612 | Aitape
# Processing Record 306 of set 612 | Codrington
# Processing Record 307 of set 612 | Mehamn
# (Total 24 cities out of 612 not found...)
# Processing Record 308 of set 612 | Barranca
# Processing Record 309 of set 612 | San Ignacio
# (Total 25 cities out of 612 not found...)
# Processing Record 310 of set 612 | Jiangyou
# Processing Record 311 of set 612 | Barrow
# Processing Record 312 of set 612 | Guthrie
# Processing Record 313 of set 612 | Makamba
# Processing Record 314 of set 612 | San Francisco
# Processing Record 315 of set 612 | Pevek
# Processing Record 316 of set 612 | Hamilton
# Processing Record 317 of set 612 | Muros
# Processing Record 318 of set 612 | Vilhena
# Processing Record 319 of set 612 | Khilok
# Processing Record 320 of set 612 | Kieta
# Processing Record 321 of set 612 | Yining
# Processing Record 322 of set 612 | Atasū
# Processing Record 323 of set 612 | Dubbo
# (Total 26 cities out of 612 not found...)
# Processing Record 324 of set 612 | Awjilah
# Processing Record 325 of set 612 | Wodonga
# Processing Record 326 of set 612 | Xianyang
# Processing Record 327 of set 612 | Verkhoyansk
# Processing Record 328 of set 612 | Rupert
# Processing Record 329 of set 612 | Tripoli
# Processing Record 330 of set 612 | Coahuayana Viejo
# Processing Record 331 of set 612 | Tshikapa
# Processing Record 332 of set 612 | San Lorenzo
# Processing Record 333 of set 612 | Bella Union
# Processing Record 334 of set 612 | Ati
# Processing Record 335 of set 612 | Salinópolis
# Processing Record 336 of set 612 | Disna
# Processing Record 337 of set 612 | Ayagoz
# (Total 27 cities out of 612 not found...)
# Processing Record 338 of set 612 | Cidreira
# Processing Record 339 of set 612 | Hofn
# Processing Record 340 of set 612 | Japura
# (Total 28 cities out of 612 not found...)
# Processing Record 341 of set 612 | Abhā
# (Total 29 cities out of 612 not found...)
# Processing Record 342 of set 612 | Huarmey
# Processing Record 343 of set 612 | Santa Vitória do Palmar
# (Total 30 cities out of 612 not found...)
# (Total 31 cities out of 612 not found...)
# (Total 32 cities out of 612 not found...)
# (Total 33 cities out of 612 not found...)
# Processing Record 344 of set 612 | Humaitá
# Processing Record 345 of set 612 | Rome
# Processing Record 346 of set 612 | Kahului
# Processing Record 347 of set 612 | Shubarkuduk
# Processing Record 348 of set 612 | Olafsvik
# (Total 34 cities out of 612 not found...)
# Processing Record 349 of set 612 | Meulaboh
# (Total 35 cities out of 612 not found...)
# Processing Record 350 of set 612 | Bandarbeyla
# Processing Record 351 of set 612 | Unity
# (Total 36 cities out of 612 not found...)
# Processing Record 352 of set 612 | Ulladulla
# Processing Record 353 of set 612 | Shahreza
# Processing Record 354 of set 612 | Talas
# Processing Record 355 of set 612 | Leningradskiy
# Processing Record 356 of set 612 | Ambilobe
# Processing Record 357 of set 612 | Methóni
# Processing Record 358 of set 612 | Kirkland Lake
# Processing Record 359 of set 612 | Jiuquan
# Processing Record 360 of set 612 | Vaitape
# Processing Record 361 of set 612 | Phek
# Processing Record 362 of set 612 | Havelock
# Processing Record 363 of set 612 | Hay River
# Processing Record 364 of set 612 | São José da Coroa Grande
# Processing Record 365 of set 612 | Kalmunai
# Processing Record 366 of set 612 | Xining
# Processing Record 367 of set 612 | Te Anau
# Processing Record 368 of set 612 | Balkanabat
# Processing Record 369 of set 612 | Takaka
# Processing Record 370 of set 612 | Plouzané
# (Total 37 cities out of 612 not found...)
# Processing Record 371 of set 612 | Pitkyaranta
# Processing Record 372 of set 612 | North Platte
# Processing Record 373 of set 612 | Sulphur
# Processing Record 374 of set 612 | Hervey Bay
# Processing Record 375 of set 612 | Warrington
# Processing Record 376 of set 612 | Inongo
# Processing Record 377 of set 612 | Scarborough
# Processing Record 378 of set 612 | Marzuq
# Processing Record 379 of set 612 | Talaya
# Processing Record 380 of set 612 | Najrān
# Processing Record 381 of set 612 | Bilma
# Processing Record 382 of set 612 | Bariloche
# Processing Record 383 of set 612 | Lisala
# Processing Record 384 of set 612 | Bima
# Processing Record 385 of set 612 | Holetown
# Processing Record 386 of set 612 | Nizwá
# Processing Record 387 of set 612 | Saint-Pierre
# Processing Record 388 of set 612 | Rūdbār
# (Total 38 cities out of 612 not found...)
# Processing Record 389 of set 612 | Atar
# Processing Record 390 of set 612 | Noumea
# Processing Record 391 of set 612 | Pemangkat
# Processing Record 392 of set 612 | Comodoro Rivadavia
# Processing Record 393 of set 612 | Porto Nacional
# Processing Record 394 of set 612 | Pochutla
# Processing Record 395 of set 612 | Eirunepé
# Processing Record 396 of set 612 | Forsytheganj
# Processing Record 397 of set 612 | Asău
# Processing Record 398 of set 612 | Kankan
# Processing Record 399 of set 612 | Kishtwār
# Processing Record 400 of set 612 | Rocha
# Processing Record 401 of set 612 | Lata
# Processing Record 402 of set 612 | Río Cuarto
# Processing Record 403 of set 612 | Grand Gaube
# Processing Record 404 of set 612 | Neuquén
# Processing Record 405 of set 612 | Oistins
# Processing Record 406 of set 612 | Broome
# Processing Record 407 of set 612 | Bogorodskoye
# Processing Record 408 of set 612 | San Jerónimo
# Processing Record 409 of set 612 | Berdychiv
# Processing Record 410 of set 612 | Labuhan
# (Total 39 cities out of 612 not found...)
# Processing Record 411 of set 612 | Liverpool
# Processing Record 412 of set 612 | Nynäshamn
# Processing Record 413 of set 612 | Sitka
# Processing Record 414 of set 612 | Roebourne
# Processing Record 415 of set 612 | Saint-François
# Processing Record 416 of set 612 | Nizhniy Tsasuchey
# Processing Record 417 of set 612 | Halifax
# (Total 40 cities out of 612 not found...)
# Processing Record 418 of set 612 | Warora
# Processing Record 419 of set 612 | Lixouri
# Processing Record 420 of set 612 | Faanui
# Processing Record 421 of set 612 | Sechura
# Processing Record 422 of set 612 | San Luis
# Processing Record 423 of set 612 | Rochester
# Processing Record 424 of set 612 | Rapid Valley
# Processing Record 425 of set 612 | Port Elizabeth
# Processing Record 426 of set 612 | Batagay-Alyta
# Processing Record 427 of set 612 | Hemsedal
# Processing Record 428 of set 612 | Srīvardhan
# Processing Record 429 of set 612 | Makkah al Mukarramah
# Processing Record 430 of set 612 | Necochea
# Processing Record 431 of set 612 | Burgos
# Processing Record 432 of set 612 | Solnechnyy
# Processing Record 433 of set 612 | Xianshuigu
# Processing Record 434 of set 612 | Lagoa
# Processing Record 435 of set 612 | Opunake
# Processing Record 436 of set 612 | Grahamstown
# Processing Record 437 of set 612 | Dwārka
# Processing Record 438 of set 612 | Nizhnevartovsk
# Processing Record 439 of set 612 | Kondagaon
# Processing Record 440 of set 612 | Léo
# Processing Record 441 of set 612 | Kibala
# Processing Record 442 of set 612 | Biak
# Processing Record 443 of set 612 | Rodrigues Alves
# Processing Record 444 of set 612 | Twentynine Palms
# Processing Record 445 of set 612 | Orël-Izumrud
# Processing Record 446 of set 612 | Yar-Sale
# Processing Record 447 of set 612 | Bowen
# Processing Record 448 of set 612 | Pulandian
# Processing Record 449 of set 612 | Pūrna
# Processing Record 450 of set 612 | Rāvar
# Processing Record 451 of set 612 | Lumeje
# Processing Record 452 of set 612 | Puerto Escondido
# Processing Record 453 of set 612 | Zyryanka
# Processing Record 454 of set 612 | Rosario
# Processing Record 455 of set 612 | Karasjok
# Processing Record 456 of set 612 | Namasuba
# Processing Record 457 of set 612 | San Sebastian
# Processing Record 458 of set 612 | Galle
# Processing Record 459 of set 612 | North Bend
# Processing Record 460 of set 612 | Porto Walter
# Processing Record 461 of set 612 | Bilibino
# Processing Record 462 of set 612 | Iralaya
# Processing Record 463 of set 612 | Kalāleh
# Processing Record 464 of set 612 | Moindou
# Processing Record 465 of set 612 | Gambo
# Processing Record 466 of set 612 | Smithers
# Processing Record 467 of set 612 | Yārāda
# Processing Record 468 of set 612 | Vao
# Processing Record 469 of set 612 | Tromsø
# (Total 41 cities out of 612 not found...)
# Processing Record 470 of set 612 | Palu
# Processing Record 471 of set 612 | Pitimbu
# Processing Record 472 of set 612 | Dhārchula
# Processing Record 473 of set 612 | Sinnamary
# Processing Record 474 of set 612 | Poum
# Processing Record 475 of set 612 | Vanimo
# Processing Record 476 of set 612 | Menzel Salem
# Processing Record 477 of set 612 | Mackenzie
# Processing Record 478 of set 612 | Kendari
# (Total 42 cities out of 612 not found...)
# Processing Record 479 of set 612 | Rawson
# (Total 43 cities out of 612 not found...)
# Processing Record 480 of set 612 | Kiryat Gat
# Processing Record 481 of set 612 | Hammerfest
# Processing Record 482 of set 612 | Loei
# Processing Record 483 of set 612 | Alibag
# Processing Record 484 of set 612 | Charters Towers
# Processing Record 485 of set 612 | Dryden
# Processing Record 486 of set 612 | Shimoda
# Processing Record 487 of set 612 | Eenhana
# Processing Record 488 of set 612 | Vila
# Processing Record 489 of set 612 | Puerto Ayacucho
# Processing Record 490 of set 612 | Bathsheba
# Processing Record 491 of set 612 | Gaspar
# Processing Record 492 of set 612 | Urusha
# Processing Record 493 of set 612 | Bakchar
# Processing Record 494 of set 612 | Boende
# Processing Record 495 of set 612 | Qaqortoq
# Processing Record 496 of set 612 | Bam
# Processing Record 497 of set 612 | Arrondissement de Rennes
# Processing Record 498 of set 612 | Kajaani
# (Total 44 cities out of 612 not found...)
# Processing Record 499 of set 612 | Zuwārah
# Processing Record 500 of set 612 | Kuytun
# Processing Record 501 of set 612 | Maragogi
# Processing Record 502 of set 612 | Rosetown
# Processing Record 503 of set 612 | Khandyga
# Processing Record 504 of set 612 | Taltal
# Processing Record 505 of set 612 | Tonekābon
# Processing Record 506 of set 612 | Clearwater
# Processing Record 507 of set 612 | Fortaleza
# Processing Record 508 of set 612 | Cherëmukhovo
# Processing Record 509 of set 612 | Launceston
# Processing Record 510 of set 612 | Ormara
# Processing Record 511 of set 612 | Mawlaik
# Processing Record 512 of set 612 | Saint Anthony
# Processing Record 513 of set 612 | Guanay
# Processing Record 514 of set 612 | Voloshka
# Processing Record 515 of set 612 | Tautira
# Processing Record 516 of set 612 | Mariental
# Processing Record 517 of set 612 | Cedar City
# Processing Record 518 of set 612 | Baie-Comeau
# Processing Record 519 of set 612 | Semey
# (Total 45 cities out of 612 not found...)
# Processing Record 520 of set 612 | Sisimiut
# Processing Record 521 of set 612 | Belaya Gora
# Processing Record 522 of set 612 | Margate
# Processing Record 523 of set 612 | Mandalgovi
# Processing Record 524 of set 612 | Vila Franca do Campo
# Processing Record 525 of set 612 | Astoria
# Processing Record 526 of set 612 | Formosa do Rio Preto
# Processing Record 527 of set 612 | Baykit
# Processing Record 528 of set 612 | Haines Junction
# Processing Record 529 of set 612 | Srednekolymsk
# Processing Record 530 of set 612 | Karratha
# Processing Record 531 of set 612 | Nemuro
# (Total 46 cities out of 612 not found...)
# Processing Record 532 of set 612 | Kota Kinabalu
# Processing Record 533 of set 612 | Envira
# Processing Record 534 of set 612 | Moreno Valley
# Processing Record 535 of set 612 | Acarí
# Processing Record 536 of set 612 | Kaeo
# Processing Record 537 of set 612 | Energetik
# Processing Record 538 of set 612 | Skibbereen
# Processing Record 539 of set 612 | Luena
# Processing Record 540 of set 612 | Kouroussa
# Processing Record 541 of set 612 | Kysyl-Syr
# (Total 47 cities out of 612 not found...)
# Processing Record 542 of set 612 | Samarai
# Processing Record 543 of set 612 | Faya
# Processing Record 544 of set 612 | Berdigestyakh
# Processing Record 545 of set 612 | Pangai
# Processing Record 546 of set 612 | Middelharnis
# Processing Record 547 of set 612 | Camacha
# Processing Record 548 of set 612 | Lavrentiya
# Processing Record 549 of set 612 | Mogadishu
# Processing Record 550 of set 612 | Manzanillo
# Processing Record 551 of set 612 | Isla Vista
# Processing Record 552 of set 612 | Luebo
# Processing Record 553 of set 612 | Majene
# Processing Record 554 of set 612 | Wuwei
# Processing Record 555 of set 612 | Dallas
# Processing Record 556 of set 612 | Santiago de Cuba
# Processing Record 557 of set 612 | Arrondissement de Saumur
# Processing Record 558 of set 612 | Mamou
# Processing Record 559 of set 612 | Lady Frere
# Processing Record 560 of set 612 | San Patricio
# Processing Record 561 of set 612 | Bonavista
# Processing Record 562 of set 612 | City of San Pedro
# (Total 48 cities out of 612 not found...)
# Processing Record 563 of set 612 | Georgiyevka
# (Total 49 cities out of 612 not found...)
#
# -------------------------------------------
# Data Retrieval Completed
# -------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# # Save CSV of all data retrieved
# city_weather_df.to_csv(output_data_file)
# city_weather_df.count()

# %%
#Display dataframe
city_weather_df.head()
# Out:
#           City Cloudiness(%) Country         Date Humidity(%)    Lat     Lng  \
# 0    Athabasca            46      CA  Jun/19/2020          86  54.72 -113.29
# 1    Cape Town             0      ZA  Jun/19/2020          37 -33.93   18.42
# 2      Aklavik            75      CA  Jun/19/2020          62  68.22 -135.01
# 3  Tuktoyaktuk            70      CA  Jun/19/2020          91  69.45 -133.04
# 4   Kosh-Agach            10      RU  Jun/19/2020          29     50   88.67
#
#   Max Temp(F) Wind Speed(mph)
# 0       45.79            2.75
# 1          73            6.93
# 2        53.6            8.05
# 3       38.19           10.13
# 4       63.52            1.74

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
font = 12
lat = city_weather_df['Lat']
max_temp = city_weather_df['Max Temp(F)']
date = city_weather_df['Date'][0]

# Print analysis
print ("Minimum Temprature is {:.2f}" .format(max_temp.min()))
print ("Average Temprature is {:.2f}" .format(max_temp.mean()))
print ("Maximun Temprature is {:.2f}" .format (max_temp.max()))  
print ("Their are {} cities temprature are greater than 100 degree (F) \n" .format (city_weather_df[city_weather_df['Max Temp(F)']> 100].count()['City']))
plt.grid(True)
# create scatter plot for city latitude with max temprature
plt.scatter(lat, max_temp, marker="o", facecolors="lightblue", edgecolors="black")
# set x axis label
plt.xlabel("Latitude", fontsize = font)
# set y axis label
plt.ylabel("Max Temperature (F)", fontsize = font)
# set chart title 
plt.title(f"City Latitude vs. Max Temparature ({date})\n", fontsize = font)
#  save png images to output folder
plt.savefig("outputdata/max_temp.png")
plt.show()
# Out:
# Minimum Temprature is 29.88
# Average Temprature is 69.73
# Maximun Temprature is 108.79
# Their are 10 cities temprature are greater than 100 degree (F)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
font = 12
lat = city_weather_df['Lat']
humidity = city_weather_df['Humidity(%)']
date = city_weather_df['Date'][1]

# Print analysis
print ("Maximum Humidity {:.2f} %".format(humidity.max()))
print ("Minimum Humidity {:.2f} %".format(humidity.min()))
print ("Average Humidity {:.2f} %".format(humidity.mean()))

plt.grid(True)
# create scatter plot for humidity by city latitude
plt.scatter(lat, humidity, marker="o", facecolors="lightblue", edgecolors="black")
# set x axis label
plt.xlabel("Latitude", fontsize = font)
# set y axis label
plt.ylabel("Humidity (%)", fontsize = font)
# set chart title 
plt.title(f"City Latitude vs. Humidity (%) ({date})\n", fontsize = font)
#  save png images to output folder
plt.savefig("outputdata/lat_humidity.png")
plt.show()
# Out:
# Maximum Humidity 100.00 %
# Minimum Humidity 3.00 %
# Average Humidity 66.83 %

# %% [markdown]
# This scatterplot is comparing a city's latitude to the Humidity percentage. From the scatterplot, you can determine that from latitudes 0 to 20, the humidity percentage is concentrated between 40 and 80 percent. You can also see that there is a concentration of extremely high humidity percentages at latitudes 40 to 80,0, and from -20 to -40.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
font = 12
lat = city_weather_df['Lat']
cloudiness = city_weather_df['Cloudiness(%)']
date = city_weather_df['Date'][1]

plt.grid(True)
# create scatter plot for cloudiness by city latitude
plt.scatter(lat, cloudiness, marker="o", facecolors="yellow", edgecolors="black")
# set x axis label
plt.xlabel("Latitude", fontsize = font)
# set y axis label
plt.ylabel("Cloudiness (%)", fontsize = font)
# set chart title 
plt.title(f"City Latitude vs. Cloudiness (%) ({date})\n", fontsize = font)
#  save png images to output folder
plt.savefig("outputdata/lat_cloudiness.png")
plt.show()

# %% [markdown]
# This scatterplot is comparing a city's latitude to the percentage of cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
font = 12
lat = city_weather_df['Lat']
wind_speed = city_weather_df['Wind Speed(mph)']
date = city_weather_df['Date'][1]

plt.grid(True)
# create scatter plot for wind speed mph by city latitude
plt.scatter(lat, wind_speed, marker="o", facecolors="red", edgecolors="black")
# set x axis label
plt.xlabel("Latitude", fontsize = font)
# set y axis label
plt.ylabel("Wind Speed (mph)", fontsize = font)
# set chart title 
plt.title(f"City Latitude vs. Wind Speed ({date})\n", fontsize = font)
#  save png images to output folder
plt.savefig("outputdata/lat_wind_speed.png")
plt.show()

# %% [markdown]
# This scatterplot is observing the Wind Speed in relation to the city latitude. From the scatterplot, you can tell that there is a high concentration of lower wind speeds from latitudes -20 to 20. It also shows that wind speeds that range from 15 mph to 35 mph occurs more likely in latitudes that range from -20 to -40 and 20 to 60.
